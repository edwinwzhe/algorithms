# %% [markdown]
# # Sorting
#
# Python implementation of sorting algorithms. Examples will focus on integer sorting unless otherwise specified.
#
# [Quick Sort](#quick_sort)
# [Insertion Sort](#insertion_sort)
# [Merge Sort](#merge_sort)
# [Tim Sort](#tim_sort)
#
#
# ### Referece
# * Visualgo: https://visualgo.net/en/sorting
# * Toptal: https://www.toptal.com/developers/sorting-algorithms

# %%
import logging 
from random import shuffle

logging.basicConfig(level=logging.DEBUG, format='%(message)s')

# %% [markdown]
# <a id='quick_sort'></a>
# ## Quick Sort
#
# #### Time Complexity
# Best - O(n logn)
# Average - O(n logn)
# Worse - O(n^2)
#
# #### Algo
# Divide and conquer is the what quick sort does. It uses the first elem in the partition as the pivot then scans through the entire partition to divide it into two smaller partitions, on the left are the values <= pivot, on the right are values > pivot. Then recursively pass the two sub-partitions into the same process.

# %%
data = [2, 3, 4, 5, 15, 19, 26, 27, 36, 38, 44, 46, 47, 48, 50]
shuffle(data)

def quick_sort(arr):
    logging.debug('------ Working on partition %s ------', arr)
    
    if len(arr) == 1:
        logging.debug('partition len == 1, return')
        return arr
    elif len(arr) == 2:
        if arr[0] > arr[1]:
            logging.debug('Swap %s(%s) with %s(%s)', 0, arr[0], 1, arr[1])
            arr[0], arr[1] = arr[1], arr[0]
            
        logging.debug('partition len == 2, return')
        return arr
    
    pivot_idx = 0
    store_idx = None
    
    for idx in range(1, len(arr)):
        if arr[idx] >= arr[pivot_idx]:
            if not store_idx:
                logging.debug('%s > %s - setting store index to %s(%s)', arr[idx], arr[pivot_idx], idx, arr[idx])
                store_idx = idx
                continue
        else:
            if store_idx:
                logging.debug('Swap idx %s(%s) with store idx %s(%s)', idx, arr[idx], store_idx, arr[store_idx])
                arr[idx], arr[store_idx] = arr[store_idx], arr[idx]
                store_idx += 1
                logging.debug('Partition updated: %s', arr)
            else:
                logging.debug('Skipping %s(%s) - store idx not set.', idx, arr[idx])
                continue
    
    logging.debug('Swapping pivot %s(%s) with store index -1 %s(%s)', pivot_idx, arr[pivot_idx], store_idx - 1, arr[store_idx - 1])
    arr[pivot_idx], arr[store_idx - 1] = arr[store_idx - 1], arr[pivot_idx]
    
    arr[0: store_idx] = quick_sort(arr[:store_idx])
    arr[store_idx: ] = quick_sort(arr[store_idx:])
    
    return arr
    
    
quick_sort(data)
# Out:
# ------ Working on partition [2, 48, 36, 38, 3, 47, 19, 5, 26, 15, 27, 46, 50, 4, 44] ------
# 48 > 2 - setting store index to 1(48)
# Swapping pivot 0(2) with store index -1 0(2)
# ------ Working on partition [2] ------
# partition len == 1, return
# ------ Working on partition [48, 36, 38, 3, 47, 19, 5, 26, 15, 27, 46, 50, 4, 44] ------
# Skipping 1(36) - store idx not set.
# Skipping 2(38) - store idx not set.
# Skipping 3(3) - store idx not set.
# Skipping 4(47) - store idx not set.
# Skipping 5(19) - store idx not set.
# Skipping 6(5) - store idx not set.
# Skipping 7(26) - store idx not set.
# Skipping 8(15) - store idx not set.
# Skipping 9(27) - store idx not set.
# Skipping 10(46) - store idx not set.
# 50 > 48 - setting store index to 11(50)
# Swap idx 12(4) with store idx 11(50)
# Partition updated: [48, 36, 38, 3, 47, 19, 5, 26, 15, 27, 46, 4, 50, 44]
# Swap idx 13(44) with store idx 12(50)
# Partition updated: [48, 36, 38, 3, 47, 19, 5, 26, 15, 27, 46, 4, 44, 50]
# Swapping pivot 0(48) with store index -1 12(44)
# ------ Working on partition [44, 36, 38, 3, 47, 19, 5, 26, 15, 27, 46, 4, 48] ------
# Skipping 1(36) - store idx not set.
# Skipping 2(38) - store idx not set.
# Skipping 3(3) - store idx not set.
# 47 > 44 - setting store index to 4(47)
# Swap idx 5(19) with store idx 4(47)
# Partition updated: [44, 36, 38, 3, 19, 47, 5, 26, 15, 27, 46, 4, 48]
# Swap idx 6(5) with store idx 5(47)
# Partition updated: [44, 36, 38, 3, 19, 5, 47, 26, 15, 27, 46, 4, 48]
# Swap idx 7(26) with store idx 6(47)
# Partition updated: [44, 36, 38, 3, 19, 5, 26, 47, 15, 27, 46, 4, 48]
# Swap idx 8(15) with store idx 7(47)
# Partition updated: [44, 36, 38, 3, 19, 5, 26, 15, 47, 27, 46, 4, 48]
# Swap idx 9(27) with store idx 8(47)
# Partition updated: [44, 36, 38, 3, 19, 5, 26, 15, 27, 47, 46, 4, 48]
# Swap idx 11(4) with store idx 9(47)
# Partition updated: [44, 36, 38, 3, 19, 5, 26, 15, 27, 4, 46, 47, 48]
# Swapping pivot 0(44) with store index -1 9(4)
# ------ Working on partition [4, 36, 38, 3, 19, 5, 26, 15, 27, 44] ------
# 36 > 4 - setting store index to 1(36)
# Swap idx 3(3) with store idx 1(36)
# Partition updated: [4, 3, 38, 36, 19, 5, 26, 15, 27, 44]
# Swapping pivot 0(4) with store index -1 1(3)
# ------ Working on partition [3, 4] ------
# partition len == 2, return
# ------ Working on partition [38, 36, 19, 5, 26, 15, 27, 44] ------
# Skipping 1(36) - store idx not set.
# Skipping 2(19) - store idx not set.
# Skipping 3(5) - store idx not set.
# Skipping 4(26) - store idx not set.
# Skipping 5(15) - store idx not set.
# Skipping 6(27) - store idx not set.
# 44 > 38 - setting store index to 7(44)
# Swapping pivot 0(38) with store index -1 6(27)
# ------ Working on partition [27, 36, 19, 5, 26, 15, 38] ------
# 36 > 27 - setting store index to 1(36)
# Swap idx 2(19) with store idx 1(36)
# Partition updated: [27, 19, 36, 5, 26, 15, 38]
# Swap idx 3(5) with store idx 2(36)
# Partition updated: [27, 19, 5, 36, 26, 15, 38]
# Swap idx 4(26) with store idx 3(36)
# Partition updated: [27, 19, 5, 26, 36, 15, 38]
# Swap idx 5(15) with store idx 4(36)
# Partition updated: [27, 19, 5, 26, 15, 36, 38]
# Swapping pivot 0(27) with store index -1 4(15)
# ------ Working on partition [15, 19, 5, 26, 27] ------
# 19 > 15 - setting store index to 1(19)
# Swap idx 2(5) with store idx 1(19)
# Partition updated: [15, 5, 19, 26, 27]
# Swapping pivot 0(15) with store index -1 1(5)
# ------ Working on partition [5, 15] ------
# partition len == 2, return
# ------ Working on partition [19, 26, 27] ------
# 26 > 19 - setting store index to 1(26)
# Swapping pivot 0(19) with store index -1 0(19)
# ------ Working on partition [19] ------
# partition len == 1, return
# ------ Working on partition [26, 27] ------
# partition len == 2, return
# ------ Working on partition [36, 38] ------
# partition len == 2, return
# ------ Working on partition [44] ------
# partition len == 1, return
# ------ Working on partition [46, 47, 48] ------
# 47 > 46 - setting store index to 1(47)
# Swapping pivot 0(46) with store index -1 0(46)
# ------ Working on partition [46] ------
# partition len == 1, return
# ------ Working on partition [47, 48] ------
# partition len == 2, return
# ------ Working on partition [50] ------
# partition len == 1, return
# [2, 3, 4, 5, 15, 19, 26, 27, 36, 38, 44, 46, 47, 48, 50]

# %% [markdown]
# <a id='insertion_sort'></a>
# ## Insertion Sort
#
# Insertion sort is similar to how most people arrange a hand of poker cards.
#
# Start with one card in your hand,
# Pick the next card and insert it into its proper sorted order,
# Repeat previous step for all cards.
#
# #### Time Complexity
# Best  - O(n)
# Average - O(n^2)
# Worse - O(n^2)
#
# #### Complexity explain (from Visualgo)
# The outer loop executes N−1 times, that's quite clear.
#
# But the number of times the inner-loop is executed depends on the input:
#
# In best-case scenario, the array is already sorted and (a[j] > X) is always false
# So no shifting of data is necessary and the inner loop runs in O(1),
# In worst-case scenario, the array is reverse sorted and (a[j] > X) is always true
# Insertion always occur at the front of the array and the inner loop runs in O(N).
# Thus, the best-case time is O(N × 1) = O(N) and the worst-case time is O(N × N) = O(N2).

# %%
data = [2, 3, 4, 5, 15, 19, 26, 27, 36, 38, 44, 46, 47, 48, 50]
shuffle(data)

def insertion_sort(data):
    logging.debug('Input data %s', data)
    sort_index = 1
    
    while sort_index < len(data):
        logging.debug('------ Iteration %s ------', sort_index)
        sort_elem = data[sort_index]
        logging.debug('Sorting index %s: %s', sort_index, sort_elem)
        
        # when sorting elemt at index 4, iterate [0, 3]
        for i in range(sort_index - 1, -1, -1):  
            logging.debug('Comparing %s with %s', sort_elem, data[i])
            
            if data[i] > sort_elem:
                logging.debug('Shifting %s to index %s', data[i], i+1)
                data[i+1] = data[i]
            elif i+1 == sort_index:
                logging.debug('No change needed')
                break
            else:
                logging.debug('Inserting %s to index %s', sort_elem, i+1)
                data[i+1] = sort_elem
                break
        else:
            logging.debug('Inserting %s to index %s', sort_elem, 0)
            data[0] = sort_elem
        
        sort_index += 1
    
    return data


insertion_sort(data)
# Out:
# Input data [2, 50, 15, 4, 48, 27, 26, 38, 3, 19, 5, 47, 46, 44, 36]
# ------ Iteration 1 ------
# Sorting index 1: 50
# Comparing 50 with 2
# No change needed
# ------ Iteration 2 ------
# Sorting index 2: 15
# Comparing 15 with 50
# Shifting 50 to index 2
# Comparing 15 with 2
# Inserting 15 to index 1
# ------ Iteration 3 ------
# Sorting index 3: 4
# Comparing 4 with 50
# Shifting 50 to index 3
# Comparing 4 with 15
# Shifting 15 to index 2
# Comparing 4 with 2
# Inserting 4 to index 1
# ------ Iteration 4 ------
# Sorting index 4: 48
# Comparing 48 with 50
# Shifting 50 to index 4
# Comparing 48 with 15
# Inserting 48 to index 3
# ------ Iteration 5 ------
# Sorting index 5: 27
# Comparing 27 with 50
# Shifting 50 to index 5
# Comparing 27 with 48
# Shifting 48 to index 4
# Comparing 27 with 15
# Inserting 27 to index 3
# ------ Iteration 6 ------
# Sorting index 6: 26
# Comparing 26 with 50
# Shifting 50 to index 6
# Comparing 26 with 48
# Shifting 48 to index 5
# Comparing 26 with 27
# Shifting 27 to index 4
# Comparing 26 with 15
# Inserting 26 to index 3
# ------ Iteration 7 ------
# Sorting index 7: 38
# Comparing 38 with 50
# Shifting 50 to index 7
# Comparing 38 with 48
# Shifting 48 to index 6
# Comparing 38 with 27
# Inserting 38 to index 5
# ------ Iteration 8 ------
# Sorting index 8: 3
# Comparing 3 with 50
# Shifting 50 to index 8
# Comparing 3 with 48
# Shifting 48 to index 7
# Comparing 3 with 38
# Shifting 38 to index 6
# Comparing 3 with 27
# Shifting 27 to index 5
# Comparing 3 with 26
# Shifting 26 to index 4
# Comparing 3 with 15
# Shifting 15 to index 3
# Comparing 3 with 4
# Shifting 4 to index 2
# Comparing 3 with 2
# Inserting 3 to index 1
# ------ Iteration 9 ------
# Sorting index 9: 19
# Comparing 19 with 50
# Shifting 50 to index 9
# Comparing 19 with 48
# Shifting 48 to index 8
# Comparing 19 with 38
# Shifting 38 to index 7
# Comparing 19 with 27
# Shifting 27 to index 6
# Comparing 19 with 26
# Shifting 26 to index 5
# Comparing 19 with 15
# Inserting 19 to index 4
# ------ Iteration 10 ------
# Sorting index 10: 5
# Comparing 5 with 50
# Shifting 50 to index 10
# Comparing 5 with 48
# Shifting 48 to index 9
# Comparing 5 with 38
# Shifting 38 to index 8
# Comparing 5 with 27
# Shifting 27 to index 7
# Comparing 5 with 26
# Shifting 26 to index 6
# Comparing 5 with 19
# Shifting 19 to index 5
# Comparing 5 with 15
# Shifting 15 to index 4
# Comparing 5 with 4
# Inserting 5 to index 3
# ------ Iteration 11 ------
# Sorting index 11: 47
# Comparing 47 with 50
# Shifting 50 to index 11
# Comparing 47 with 48
# Shifting 48 to index 10
# Comparing 47 with 38
# Inserting 47 to index 9
# ------ Iteration 12 ------
# Sorting index 12: 46
# Comparing 46 with 50
# Shifting 50 to index 12
# Comparing 46 with 48
# Shifting 48 to index 11
# Comparing 46 with 47
# Shifting 47 to index 10
# Comparing 46 with 38
# Inserting 46 to index 9
# ------ Iteration 13 ------
# Sorting index 13: 44
# Comparing 44 with 50
# Shifting 50 to index 13
# Comparing 44 with 48
# Shifting 48 to index 12
# Comparing 44 with 47
# Shifting 47 to index 11
# Comparing 44 with 46
# Shifting 46 to index 10
# Comparing 44 with 38
# Inserting 44 to index 9
# ------ Iteration 14 ------
# Sorting index 14: 36
# Comparing 36 with 50
# Shifting 50 to index 14
# Comparing 36 with 48
# Shifting 48 to index 13
# Comparing 36 with 47
# Shifting 47 to index 12
# Comparing 36 with 46
# Shifting 46 to index 11
# Comparing 36 with 44
# Shifting 44 to index 10
# Comparing 36 with 38
# Shifting 38 to index 9
# Comparing 36 with 27
# Inserting 36 to index 8
# [2, 3, 4, 5, 15, 19, 26, 27, 36, 38, 44, 46, 47, 48, 50]

# %% [markdown]
# ## Binary Insertion Sort

# %%
def binary_search(the_array, item, start, end):
    logging.debug('Binary searching %s from %s', item, the_array[start: end+1])
    if start == end:
        if the_array[start] > item:
            return start
        else:
            return start + 1
    if start > end:
        return start

    mid = round((start + end)/ 2)

    if the_array[mid] < item:
        return binary_search(the_array, item, mid + 1, end)

    elif the_array[mid] > item:
        return binary_search(the_array, item, start, mid - 1)

    else:
        return mid

"""
Insertion sort that timsort uses if the array size is small or if
the size of the "run" is small
"""
def insertion_sort(the_array):
    l = len(the_array)
    for index in range(1, l):
        value = the_array[index]
        pos = binary_search(the_array, value, 0, index - 1)
        the_array = the_array[:pos] + [value] + the_array[pos:index] + the_array[index+1:]
    return the_array

insertion_sort(data)
# Out:
# Binary searching 3 from [2]
# Binary searching 4 from [2, 3]
# Binary searching 4 from [3]
# Binary searching 5 from [2, 3, 4]
# Binary searching 5 from [4]
# Binary searching 15 from [2, 3, 4, 5]
# Binary searching 15 from [5]
# Binary searching 19 from [2, 3, 4, 5, 15]
# Binary searching 19 from [5, 15]
# Binary searching 19 from []
# Binary searching 26 from [2, 3, 4, 5, 15, 19]
# Binary searching 26 from [5, 15, 19]
# Binary searching 26 from [19]
# Binary searching 27 from [2, 3, 4, 5, 15, 19, 26]
# Binary searching 27 from [15, 19, 26]
# Binary searching 27 from [26]
# Binary searching 36 from [2, 3, 4, 5, 15, 19, 26, 27]
# Binary searching 36 from [19, 26, 27]
# Binary searching 36 from [27]
# Binary searching 38 from [2, 3, 4, 5, 15, 19, 26, 27, 36]
# Binary searching 38 from [19, 26, 27, 36]
# Binary searching 38 from [27, 36]
# Binary searching 38 from []
# Binary searching 44 from [2, 3, 4, 5, 15, 19, 26, 27, 36, 38]
# Binary searching 44 from [19, 26, 27, 36, 38]
# Binary searching 44 from [36, 38]
# Binary searching 44 from [38]
# Binary searching 46 from [2, 3, 4, 5, 15, 19, 26, 27, 36, 38, 44]
# Binary searching 46 from [26, 27, 36, 38, 44]
# Binary searching 46 from [38, 44]
# Binary searching 46 from []
# Binary searching 47 from [2, 3, 4, 5, 15, 19, 26, 27, 36, 38, 44, 46]
# Binary searching 47 from [27, 36, 38, 44, 46]
# Binary searching 47 from [44, 46]
# Binary searching 47 from [46]
# Binary searching 48 from [2, 3, 4, 5, 15, 19, 26, 27, 36, 38, 44, 46, 47]
# Binary searching 48 from [27, 36, 38, 44, 46, 47]
# Binary searching 48 from [46, 47]
# Binary searching 48 from []
# Binary searching 50 from [2, 3, 4, 5, 15, 19, 26, 27, 36, 38, 44, 46, 47, 48]
# Binary searching 50 from [27, 36, 38, 44, 46, 47, 48]
# Binary searching 50 from [46, 47, 48]
# Binary searching 50 from [48]
# [2, 3, 4, 5, 15, 19, 26, 27, 36, 38, 44, 46, 47, 48, 50]

# %% [markdown]
# <a id='merge_sort'></a>
# ## Merge Sort
#
# Given an array of N items, Merge Sort will:
#
# Merge each pair of individual element (which is by default, sorted) into sorted arrays of 2 elements,
# Merge each pair of sorted arrays of 2 elements into sorted arrays of 4 elements,
# Repeat the process...,
# Final step: Merge 2 sorted arrays of N/2 elements (for simplicity of this discussion, we assume that N is even) to obtain a fully sorted array of N elements.
# This is just the general idea and we need a few more details before we can discuss the true form of Merge Sort.
#
#
# We will dissect this Merge Sort algorithm by first discussing its most important sub-routine: The O(N) merge.
# Given two sorted array, A and B, of size N1 and N2, we can efficiently merge them into one larger combined sorted array of size N = N1+N2, in O(N) time.
# This is achieved by simply comparing the front of the two arrays and take the smaller of the two at all times.
# However, this simple but fast O(N) merge sub-routine will need additional array to do this merging correctly. See the next slide.
#
# #### Time Complexity
# Best  - O(n logn)
# Average - O(n logn)
# Worse - O(n logn)

# %%
data = [2, 3, 4, 5, 15, 19, 26, 27, 36, 38, 44, 46, 47, 48, 50]
shuffle(data)

def merge(left, right):
    logging.debug('Merging %s and %s', left, right)
    
    merged_list = []
    
    while left or right:
        if not right:
            logging.debug('Picked %s from left group', left[0])
            merged_list.append(left.pop(0))
        elif not left:
            logging.debug('Picked %s from right group', right[0])
            merged_list.append(right.pop(0))
        else:
            if left[0] < right[0]:
                logging.debug('Picked %s from left group', left[0])
                merged_list.append(left.pop(0))
            else:
                logging.debug('Picked %s from right group', right[0])
                merged_list.append(right.pop(0))
        
    logging.debug('Merge result %s', merged_list)
    return merged_list
            

def merge_sort(data):
    logging.debug('Input data %s', data)
    
    insert_index = 0
    size = 1
    iter_num = 0
    
    while size < len(data):
        
        while True:
            iter_num += 1
            logging.debug('------ Iteration %s, insert index %s, group size %s ------', iter_num, insert_index, size)
            
            if insert_index + size >= len(data):
                 break

            left = data[insert_index: insert_index + size]
            right = data[insert_index + size: insert_index + size * 2]

            merged_list = merge(left, right)
            data[insert_index: insert_index + len(merged_list)] = merged_list
            
            insert_index += len(merged_list)
        
        insert_index = 0
        size *= 2
                
    return data


merge_sort(data)
# Out:
# Input data [44, 36, 48, 38, 5, 46, 26, 27, 3, 15, 19, 47, 4, 2, 50]
# ------ Iteration 1, insert index 0, group size 1 ------
# Merging [44] and [36]
# Picked 36 from right group
# Picked 44 from left group
# Merge result [36, 44]
# ------ Iteration 2, insert index 2, group size 1 ------
# Merging [48] and [38]
# Picked 38 from right group
# Picked 48 from left group
# Merge result [38, 48]
# ------ Iteration 3, insert index 4, group size 1 ------
# Merging [5] and [46]
# Picked 5 from left group
# Picked 46 from right group
# Merge result [5, 46]
# ------ Iteration 4, insert index 6, group size 1 ------
# Merging [26] and [27]
# Picked 26 from left group
# Picked 27 from right group
# Merge result [26, 27]
# ------ Iteration 5, insert index 8, group size 1 ------
# Merging [3] and [15]
# Picked 3 from left group
# Picked 15 from right group
# Merge result [3, 15]
# ------ Iteration 6, insert index 10, group size 1 ------
# Merging [19] and [47]
# Picked 19 from left group
# Picked 47 from right group
# Merge result [19, 47]
# ------ Iteration 7, insert index 12, group size 1 ------
# Merging [4] and [2]
# Picked 2 from right group
# Picked 4 from left group
# Merge result [2, 4]
# ------ Iteration 8, insert index 14, group size 1 ------
# ------ Iteration 9, insert index 0, group size 2 ------
# Merging [36, 44] and [38, 48]
# Picked 36 from left group
# Picked 38 from right group
# Picked 44 from left group
# Picked 48 from right group
# Merge result [36, 38, 44, 48]
# ------ Iteration 10, insert index 4, group size 2 ------
# Merging [5, 46] and [26, 27]
# Picked 5 from left group
# Picked 26 from right group
# Picked 27 from right group
# Picked 46 from left group
# Merge result [5, 26, 27, 46]
# ------ Iteration 11, insert index 8, group size 2 ------
# Merging [3, 15] and [19, 47]
# Picked 3 from left group
# Picked 15 from left group
# Picked 19 from right group
# Picked 47 from right group
# Merge result [3, 15, 19, 47]
# ------ Iteration 12, insert index 12, group size 2 ------
# Merging [2, 4] and [50]
# Picked 2 from left group
# Picked 4 from left group
# Picked 50 from right group
# Merge result [2, 4, 50]
# ------ Iteration 13, insert index 15, group size 2 ------
# ------ Iteration 14, insert index 0, group size 4 ------
# Merging [36, 38, 44, 48] and [5, 26, 27, 46]
# Picked 5 from right group
# Picked 26 from right group
# Picked 27 from right group
# Picked 36 from left group
# Picked 38 from left group
# Picked 44 from left group
# Picked 46 from right group
# Picked 48 from left group
# Merge result [5, 26, 27, 36, 38, 44, 46, 48]
# ------ Iteration 15, insert index 8, group size 4 ------
# Merging [3, 15, 19, 47] and [2, 4, 50]
# Picked 2 from right group
# Picked 3 from left group
# Picked 4 from right group
# Picked 15 from left group
# Picked 19 from left group
# Picked 47 from left group
# Picked 50 from right group
# Merge result [2, 3, 4, 15, 19, 47, 50]
# ------ Iteration 16, insert index 15, group size 4 ------
# ------ Iteration 17, insert index 0, group size 8 ------
# Merging [5, 26, 27, 36, 38, 44, 46, 48] and [2, 3, 4, 15, 19, 47, 50]
# Picked 2 from right group
# Picked 3 from right group
# Picked 4 from right group
# Picked 5 from left group
# Picked 15 from right group
# Picked 19 from right group
# Picked 26 from left group
# Picked 27 from left group
# Picked 36 from left group
# Picked 38 from left group
# Picked 44 from left group
# Picked 46 from left group
# Picked 47 from right group
# Picked 48 from left group
# Picked 50 from right group
# Merge result [2, 3, 4, 5, 15, 19, 26, 27, 36, 38, 44, 46, 47, 48, 50]
# ------ Iteration 18, insert index 15, group size 8 ------
# [2, 3, 4, 5, 15, 19, 26, 27, 36, 38, 44, 46, 47, 48, 50]

# %% [markdown]
# <a id='tim_sort'></a>
# ## Tim Sort
#
#
#
# #### Time Complexity
# Best  - O(n)
# Average - O(n logn)
# Worse - O(n logn)

# %%
data = [2, 3, 4, 5, 15, 19, 26, 27, 36, 38, 44, 46, 47, 48, 50]
shuffle(data)


# based off of this code https://gist.github.com/nandajavarma/a3a6b62f34e74ec4c31674934327bbd3
# Brandon Skerritt
# https://skerritt.tech
def merge(left, right):
    """Takes two sorted lists and returns a single sorted list by comparing the
    elements one at a time.
    [1, 2, 3, 4, 5, 6]
    """
    logging.debug('Merging %s with %s', left, right)
    if not left:
        return right
    if not right:
        return left
    if left[0] < right[0]:
        return [left[0]] + merge(left[1:], right)
    return [right[0]] + merge(left, right[1:])

def timsort(the_array):
    logging.debug('Sorting input %s', the_array)
    runs, sorted_runs = [], []
    length = len(the_array)
    new_run = [the_array[0]]

    # for every i in the range of 1 to length of array
    for i in range(1, length):
        # if i is at the end of the list
        if i == length - 1:
            new_run.append(the_array[i])
            runs.append(new_run)
            logging.debug('Appending new run to runs 1: %s -> %s', new_run, runs)
            break
            
        # if the i'th element of the array is less than the one before it
        if the_array[i] < the_array[i-1]:
            # if new_run is set to None (NULL)
            if not new_run:
                runs.append([the_array[i]])
                logging.debug('Appending to new run 1: %s -> %s', [the_array[i]], runs)
                new_run.append(the_array[i])
            else:
                runs.append(new_run)
                logging.debug('Appending new run to runs 2: %s -> %s', new_run, runs)
                new_run = []
        # else if its equal to or more than
        else:
            new_run.append(the_array[i])
            logging.debug('Appending to new run 2: %s -> %s', the_array[i], runs)
            
    logging.debug('Created runs %s', runs)

    # for every item in runs, append it using insertion sort
    for item in runs:
        sorted_item = insertion_sort(item)
        logging.debug('Add %s to sorted runs', sorted_item)
        
        sorted_runs.append(sorted_item)
    
    # for every run in sorted_runs, merge them
    sorted_array = []
    for run in sorted_runs:
        sorted_array = merge(sorted_array, run)
        logging.debug('Merged %s -> %s', run, sorted_array)

    return sorted_array

timsort(data)
# Out:
# Sorting input [19, 3, 44, 4, 47, 48, 36, 5, 2, 15, 46, 38, 26, 50, 27]
# Appending new run to runs 2: [19] -> [[19]]
# Appending to new run 2: 44 -> [[19]]
# Appending new run to runs 2: [44] -> [[19], [44]]
# Appending to new run 2: 47 -> [[19], [44]]
# Appending to new run 2: 48 -> [[19], [44]]
# Appending new run to runs 2: [47, 48] -> [[19], [44], [47, 48]]
# Appending to new run 1: [5] -> [[19], [44], [47, 48], [5]]
# Appending new run to runs 2: [5] -> [[19], [44], [47, 48], [5], [5]]
# Appending to new run 2: 15 -> [[19], [44], [47, 48], [5], [5]]
# Appending to new run 2: 46 -> [[19], [44], [47, 48], [5], [5]]
# Appending new run to runs 2: [15, 46] -> [[19], [44], [47, 48], [5], [5], [15, 46]]
# Appending to new run 1: [26] -> [[19], [44], [47, 48], [5], [5], [15, 46], [26]]
# Appending to new run 2: 50 -> [[19], [44], [47, 48], [5], [5], [15, 46], [26]]
# Appending new run to runs 1: [26, 50, 27] -> [[19], [44], [47, 48], [5], [5], [15, 46], [26], [26, 50, 27]]
# Created runs [[19], [44], [47, 48], [5], [5], [15, 46], [26], [26, 50, 27]]
# Add [19] to sorted runs
# Add [44] to sorted runs
# Binary searching 48 from [47]
# Add [47, 48] to sorted runs
# Add [5] to sorted runs
# Add [5] to sorted runs
# Binary searching 46 from [15]
# Add [15, 46] to sorted runs
# Add [26] to sorted runs
# Binary searching 50 from [26]
# Binary searching 27 from [26, 50]
# Binary searching 27 from [50]
# Add [26, 27, 50] to sorted runs
# Merging [] with [19]
# Merged [19] -> [19]
# Merging [19] with [44]
# Merging [] with [44]
# Merged [44] -> [19, 44]
# Merging [19, 44] with [47, 48]
# Merging [44] with [47, 48]
# Merging [] with [47, 48]
# Merged [47, 48] -> [19, 44, 47, 48]
# Merging [19, 44, 47, 48] with [5]
# Merging [19, 44, 47, 48] with []
# Merged [5] -> [5, 19, 44, 47, 48]
# Merging [5, 19, 44, 47, 48] with [5]
# Merging [5, 19, 44, 47, 48] with []
# Merged [5] -> [5, 5, 19, 44, 47, 48]
# Merging [5, 5, 19, 44, 47, 48] with [15, 46]
# Merging [5, 19, 44, 47, 48] with [15, 46]
# Merging [19, 44, 47, 48] with [15, 46]
# Merging [19, 44, 47, 48] with [46]
# Merging [44, 47, 48] with [46]
# Merging [47, 48] with [46]
# Merging [47, 48] with []
# Merged [15, 46] -> [5, 5, 15, 19, 44, 46, 47, 48]
# Merging [5, 5, 15, 19, 44, 46, 47, 48] with [26]
# Merging [5, 15, 19, 44, 46, 47, 48] with [26]
# Merging [15, 19, 44, 46, 47, 48] with [26]
# Merging [19, 44, 46, 47, 48] with [26]
# Merging [44, 46, 47, 48] with [26]
# Merging [44, 46, 47, 48] with []
# Merged [26] -> [5, 5, 15, 19, 26, 44, 46, 47, 48]
# Merging [5, 5, 15, 19, 26, 44, 46, 47, 48] with [26, 27, 50]
# Merging [5, 15, 19, 26, 44, 46, 47, 48] with [26, 27, 50]
# Merging [15, 19, 26, 44, 46, 47, 48] with [26, 27, 50]
# Merging [19, 26, 44, 46, 47, 48] with [26, 27, 50]
# Merging [26, 44, 46, 47, 48] with [26, 27, 50]
# Merging [26, 44, 46, 47, 48] with [27, 50]
# Merging [44, 46, 47, 48] with [27, 50]
# Merging [44, 46, 47, 48] with [50]
# Merging [46, 47, 48] with [50]
# Merging [47, 48] with [50]
# Merging [48] with [50]
# Merging [] with [50]
# Merged [26, 27, 50] -> [5, 5, 15, 19, 26, 26, 27, 44, 46, 47, 48, 50]
# [5, 5, 15, 19, 26, 26, 27, 44, 46, 47, 48, 50]
